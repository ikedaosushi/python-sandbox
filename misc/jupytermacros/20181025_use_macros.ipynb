# %%
# %store -r __imp
# %store -r __mpl

# %%
__imp
# Out:
# Your libraries have been loaded

# %%
__mpl
# Out:
# Your matplotlib params have been set

# %%
plt.rcParams["font.family"] = "YuGothic"
plt.plot(np.linspace(0, 100, 101), 2 * np.linspace(0, 100, 101))
plt.ylabel('日本語のラベルY')
plt.xlabel('日本語のラベルX')
# Out:
# Text(0.5,0,'日本語のラベルX')
