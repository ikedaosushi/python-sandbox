# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from IPython.display import Image

import os, sys, re, datetime, time
from pathlib import Path

pj_dir = Path(os.getcwd()).parents[0]
data_dir = pj_dir/'data'
img_dir = pj_dir/'images'
src_dir = pj_dir/'src'
sys.path.append(str(src_dir))

from matplotlib import pyplot as plt
import japanize_matplotlib
import seaborn as sns
plt.style.use("bmh")
import numpy as np
import pandas as pd
import dask.dataframe as dd

from tqdm import tqdm_notebook
from dotenv import load_dotenv

# %%
from heamy.dataset import Dataset
from heamy.estimator import Regressor, Classifier
from heamy.pipeline import ModelsPipeline

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor

# %%
from catboost import CatBoostClassifier, CatBoostRegressor, Pool, cv
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_absolute_error

# %%
from sklearn.model_selection import train_test_split
from catboost.datasets import titanic
import numpy as np

# %%
from sklearn.datasets import load_boston

# %% [markdown]
# # From tutorial

# %% [markdown]
# # Stacking

# %%
# load boston dataset from sklearn
from sklearn.datasets import load_boston
data = load_boston()
X, y = data['data'], data['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=111)

# create dataset
dataset = Dataset(X_train,y_train,X_test)

# initialize RandomForest & LinearRegression
model_rf = Regressor(dataset=dataset, estimator=RandomForestRegressor, parameters={'n_estimators': 50}, name='rf')
model_lr = Regressor(dataset=dataset, estimator=LinearRegression, parameters={'normalize': True}, name='lr')

# Stack two models
# Returns new dataset with out-of-fold predictions
pipeline = ModelsPipeline(model_rf,model_lr)
stack_ds = pipeline.stack(k=10,seed=111)

# Train LinearRegression on stacked data (second stage)
stacker = Regressor(dataset=stack_ds, estimator=LinearRegression)
results = stacker.predict()
# Validate results using 10 fold cross-validation
results = stacker.validate(k=10,scorer=mean_absolute_error)
# Out:
# Metric: mean_absolute_error
# Folds accuracy: [2.6547554270930753, 1.530020684497064, 1.9954728439069227, 2.038517331082455, 2.590018535101311, 2.7001268670192555, 1.6441529920970588, 2.5659198546681714, 2.472405404399628, 2.394314223788695]
# Mean accuracy: 2.2585704163653633
# Standard Deviation: 0.4057517903676271
# Variance: 0.16463451538653479

# %% [markdown]
# ## Blending

# %%
# load boston dataset from sklearn
from sklearn.datasets import load_boston
data = load_boston()
X, y = data['data'], data['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=111)

# create dataset
dataset = Dataset(X_train,y_train,X_test)

# initialize RandomForest & LinearRegression
model_rf = Regressor(dataset=dataset, estimator=RandomForestRegressor, parameters={'n_estimators': 50},name='rf')
model_lr = Regressor(dataset=dataset, estimator=LinearRegression, parameters={'normalize': True},name='lr')

# Stack two models
# Returns new dataset with out-of-fold predictions
pipeline = ModelsPipeline(model_rf,model_lr)
stack_ds = pipeline.blend(proportion=0.2,seed=111)

# Train LinearRegression on stacked data (second stage)
stacker = Regressor(dataset=stack_ds, estimator=LinearRegression)
results = stacker.predict()
# Validate results using 10 fold cross-validation
results = stacker.validate(k=10,scorer=mean_absolute_error)
# Out:
# Metric: mean_absolute_error
# Folds accuracy: [2.592903546519196, 1.3830221732582768, 1.1235856379677305, 3.8563833889182817, 1.925512881703217, 1.2012079643334295, 3.5078089382585635, 3.455189841415516, 1.2933569204511624, 3.2398309632533264]
# Mean accuracy: 2.35788022560787
# Standard Deviation: 1.0361893017777448
# Variance: 1.0736882691186505

# %% [markdown]
# ## Weight average

# %%
# load boston dataset from sklearn
from sklearn.datasets import load_boston
data = load_boston()
X, y = data['data'], data['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=111)

# create dataset
dataset = Dataset(X_train,y_train,X_test)

model_rf = Regressor(dataset=dataset, estimator=RandomForestRegressor, parameters={'n_estimators': 151},name='rf')
model_lr = Regressor(dataset=dataset, estimator=LinearRegression, parameters={'normalize': True},name='lr')
model_knn = Regressor(dataset=dataset, estimator=KNeighborsRegressor, parameters={'n_neighbors': 15},name='knn')

pipeline = ModelsPipeline(model_rf,model_lr,model_knn)

weights = pipeline.find_weights(mean_absolute_error)
result = pipeline.weight(weights)
# Out:
# Best Score (mean_absolute_error): 2.0970365230474086
# Best Weights: [8.99402665e-01 1.00597335e-01 1.31295661e-16]

# %% [markdown]
# # Own

# %%
seed = 42

# %% [markdown]
# ### Load Data

# %%
import pandas as pd
from sklearn.datasets import load_wine

# %%
X, y = load_boston(return_X_y=True)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.05, random_state=seed)

# %% [markdown]
# ### some models

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import cross_val_score

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
models_dic = {
    'rf': RandomForestRegressor(n_estimators=50, random_state=seed),
    'lr': LinearRegression(normalize=True),
    'kr': KNeighborsRegressor(),
    'cr': CatBoostRegressor(custom_metric=['MAE'], random_seed=seed, logging_level='Silent')
}

# %%
for name, model in models_dic.items():
    kfold = KFold(n_splits=10, random_state=seed)
    cv_results = cross_val_score(model, X_train, y_train, cv=kfold, scoring="neg_mean_absolute_error")
    print(name, ': ', - np.mean(cv_results))
# Out:
# rf :  2.2253083333333334
# lr :  3.4667269295247807
# kr :  4.448708333333333
# cr :  2.195290136923679

# %% [markdown]
# ### Stacking

# %%
dataset = Dataset(X_train, y_train, X_test)

models = [
    Regressor(dataset=dataset, estimator=RandomForestRegressor, parameters={'n_estimators': 50, 'random_state': seed}, name='rf'),
    Regressor(dataset=dataset, estimator=LinearRegression, parameters={'normalize': True}, name='lr'),
    Regressor(dataset=dataset, estimator=KNeighborsRegressor, name='kr'),
    Regressor(dataset=dataset, estimator=CatBoostRegressor, parameters={'custom_metric': ['MAE'], 'random_seed': seed, 'logging_level': 'Silent'}, name='cr')
]

pipeline = ModelsPipeline(*models)
stack_ds = pipeline.stack(k=10, seed=seed)

stacker = Regressor(dataset=stack_ds, estimator=LinearRegression)
y_trues, y_preds = stacker.validate(k=10)

cv_results = []
for y_true, y_pred in zip(y_trues, y_preds):
    cv_result = mean_absolute_error(y_true, y_pred)
    cv_results.append(cv_result)
print('stacking: ', np.mean(cv_results))
# Out:
# stacking:  2.1563606299364295

# %% [markdown]
# ### Blending

# %%
pipeline = ModelsPipeline(*models)
stack_ds = pipeline.blend(proportion=0.2, seed=seed)

stacker = Regressor(dataset=stack_ds, estimator=LinearRegression)
y_trues, y_preds = stacker.validate(k=10)

cv_results = []
for y_true, y_pred in zip(y_trues, y_preds):
    cv_result = mean_absolute_error(y_true, y_pred)
    cv_results.append(cv_result)
print('blending: ', np.mean(cv_results))
# Out:
# stacking:  3.0442182736964476

# %% [markdown]
# ### Weighted Average

# %%
pipeline = ModelsPipeline(*models)
weights = pipeline.find_weights(mean_absolute_error)
pipeline_apply = pipeline.weight(weights)
cv_results = pipeline_apply.validate(scorer=mean_absolute_error, k=10)
print('weighted average: ', np.mean(cv_results))
# Out:
# Best Score (mean_absolute_error): 1.9893582436999917
# Best Weights: [2.18887575e-01 1.94297608e-17 7.96579612e-18 7.81112425e-01]
# Metric: mean_absolute_error
# Folds accuracy: [1.978630110432124, 2.137259891149993, 2.145816457861829, 1.4496619629760552, 2.3527743239776573, 2.910698591290202, 2.0799869355876592, 1.74754010963542, 3.114361238261376, 2.3891019916145555]
# Mean accuracy: 2.2305831612786875
# Standard Deviation: 0.47211251675696475
# Variance: 0.22289022847859533
# weighted average:  2.2305831612786875

# %% [markdown]
# # pystacknet

# %%
from pystacknet.pystacknet import StackNetRegressor

# %%
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.linear_model import Ridge
from xgboost import XGBRegressor

# %%
models=[ 
    # 1st level
    [
        RandomForestRegressor(n_estimators=50, random_state=seed),
        LinearRegression(normalize=True),
        CatBoostRegressor(custom_metric=['MAE'], random_seed=seed, logging_level='Silent')     
    ],
    # 2nd level
    [
        Ridge(normalize=True),
        ExtraTreesRegressor(random_state=seed),
        XGBRegressor(random_state=seed)
    ],
    [
        LinearRegression(normalize=True)
    ]
]

# %%
model = StackNetRegressor(
    models, folds=10,
    restacking=False, use_retraining=True,
    random_state=seed, n_jobs=-1, verbose=1
)
kfold = KFold(n_splits=10, random_state=seed)
cv_results = cross_val_score(model, X_train, y_train, cv=kfold, scoring="neg_mean_absolute_error")
print(name, ': ', -np.mean(cv_results))
# Out:
# ====================== Start of Level 0 ======================
# Input Dimensionality 13 at Level 0
# 3 models included in Level 0
# Fold 1/10 , model 0 , custom===4.279341
# Fold 1/10 , model 1 , custom===6.597792
# Fold 1/10 , model 2 , custom===4.060826
# =========== end of fold 1 in level 0 ===========
# Fold 2/10 , model 0 , custom===3.346264
# Fold 2/10 , model 1 , custom===5.585476
# Fold 2/10 , model 2 , custom===3.643938
# =========== end of fold 2 in level 0 ===========
# Fold 3/10 , model 0 , custom===2.557439
# Fold 3/10 , model 1 , custom===3.693772
# Fold 3/10 , model 2 , custom===3.141906
# =========== end of fold 3 in level 0 ===========
# Fold 4/10 , model 0 , custom===3.528272
# Fold 4/10 , model 1 , custom===4.962491
# Fold 4/10 , model 2 , custom===3.101538
# =========== end of fold 4 in level 0 ===========
# Fold 5/10 , model 0 , custom===4.177779
# Fold 5/10 , model 1 , custom===5.794933
# Fold 5/10 , model 2 , custom===3.672188
# =========== end of fold 5 in level 0 ===========
# Fold 6/10 , model 0 , custom===4.033046
# Fold 6/10 , model 1 , custom===6.208602
# Fold 6/10 , model 2 , custom===3.420754
# =========== end of fold 6 in level 0 ===========
# Fold 7/10 , model 0 , custom===3.373084
# Fold 7/10 , model 1 , custom===4.740010
# Fold 7/10 , model 2 , custom===4.007555
# =========== end of fold 7 in level 0 ===========
# Fold 8/10 , model 0 , custom===3.706942
# Fold 8/10 , model 1 , custom===3.969787
# Fold 8/10 , model 2 , custom===2.560778
# =========== end of fold 8 in level 0 ===========
# Fold 9/10 , model 0 , custom===2.435956
# Fold 9/10 , model 1 , custom===3.594397
# Fold 9/10 , model 2 , custom===2.196563
# =========== end of fold 9 in level 0 ===========
# Fold 10/10 , model 0 , custom===3.437467
# Fold 10/10 , model 1 , custom===4.971873
# Fold 10/10 , model 2 , custom===3.020822
# =========== end of fold 10 in level 0 ===========
# Output dimensionality of level 0 is 3
# ====================== End of Level 0 ======================
#  level 0 lasted 67.372773 seconds
# ====================== Start of Level 1 ======================
# Input Dimensionality 3 at Level 1
# 3 models included in Level 1
# Fold 1/10 , model 0 , custom===5.192089
# Fold 1/10 , model 1 , custom===4.433925
# Fold 1/10 , model 2 , custom===4.437456
# =========== end of fold 1 in level 1 ===========
# Fold 2/10 , model 0 , custom===3.801814
# Fold 2/10 , model 1 , custom===3.479834
# Fold 2/10 , model 2 , custom===3.032982
# =========== end of fold 2 in level 1 ===========
# Fold 3/10 , model 0 , custom===3.284951
# Fold 3/10 , model 1 , custom===2.830267
# Fold 3/10 , model 2 , custom===2.797768
# =========== end of fold 3 in level 1 ===========
# Fold 4/10 , model 0 , custom===4.210844
# Fold 4/10 , model 1 , custom===3.076010
# Fold 4/10 , model 2 , custom===2.758723
# =========== end of fold 4 in level 1 ===========
# Fold 5/10 , model 0 , custom===3.699202
# Fold 5/10 , model 1 , custom===4.455290
# Fold 5/10 , model 2 , custom===4.446796
# =========== end of fold 5 in level 1 ===========
# Fold 6/10 , model 0 , custom===5.068164
# Fold 6/10 , model 1 , custom===3.407983
# Fold 6/10 , model 2 , custom===3.024262
# =========== end of fold 6 in level 1 ===========
# Fold 7/10 , model 0 , custom===4.872566
# Fold 7/10 , model 1 , custom===4.570325
# Fold 7/10 , model 2 , custom===4.152647
# =========== end of fold 7 in level 1 ===========
# Fold 8/10 , model 0 , custom===3.507361
# Fold 8/10 , model 1 , custom===3.515178
# Fold 8/10 , model 2 , custom===3.452181
# =========== end of fold 8 in level 1 ===========
# Fold 9/10 , model 0 , custom===2.869488
# Fold 9/10 , model 1 , custom===2.324096
# Fold 9/10 , model 2 , custom===2.108594
# =========== end of fold 9 in level 1 ===========
# Fold 10/10 , model 0 , custom===4.155812
# Fold 10/10 , model 1 , custom===3.384479
# Fold 10/10 , model 2 , custom===3.306422
# =========== end of fold 10 in level 1 ===========
# Output dimensionality of level 1 is 3
# ====================== End of Level 1 ======================
#  level 1 lasted 4.441921 seconds
# ====================== Start of Level 2 ======================
# Input Dimensionality 3 at Level 2
# 1 models included in Level 2
# Fold 1/10 , model 0 , custom===4.305170
# =========== end of fold 1 in level 2 ===========
# Fold 2/10 , model 0 , custom===3.256365
# =========== end of fold 2 in level 2 ===========
# Fold 3/10 , model 0 , custom===2.721836
# =========== end of fold 3 in level 2 ===========
# Fold 4/10 , model 0 , custom===2.877814
# =========== end of fold 4 in level 2 ===========
# Fold 5/10 , model 0 , custom===4.447640
# =========== end of fold 5 in level 2 ===========
# Fold 6/10 , model 0 , custom===3.464620
# =========== end of fold 6 in level 2 ===========
# Fold 7/10 , model 0 , custom===3.767020
# =========== end of fold 7 in level 2 ===========
# Fold 8/10 , model 0 , custom===3.171747
# =========== end of fold 8 in level 2 ===========
# Fold 9/10 , model 0 , custom===2.005747
# =========== end of fold 9 in level 2 ===========
# Fold 10/10 , model 0 , custom===3.291404
# =========== end of fold 10 in level 2 ===========
# Output dimensionality of level 2 is 1
# ====================== End of Level 2 ======================
#  level 2 lasted 4.357440 seconds
# ====================== End of fit ======================
#  fit() lasted 76.172760 seconds
# ====================== Start of Level 0 ======================
# 1 estimators included in Level 0
# ====================== Start of Level 1 ======================
# 1 estimators included in Level 1
# ====================== Start of Level 2 ======================
# 1 estimators included in Level 2
# ====================== Start of Level 0 ======================
# Input Dimensionality 13 at Level 0
# 3 models included in Level 0
# Fold 1/10 , model 0 , custom===3.725393
# Fold 1/10 , model 1 , custom===7.018837
# Fold 1/10 , model 2 , custom===4.910413
# =========== end of fold 1 in level 0 ===========
# Fold 2/10 , model 0 , custom===3.048714
# Fold 2/10 , model 1 , custom===4.124804
# Fold 2/10 , model 2 , custom===2.906457
# =========== end of fold 2 in level 0 ===========
# Fold 3/10 , model 0 , custom===2.464353
# Fold 3/10 , model 1 , custom===3.660245
# Fold 3/10 , model 2 , custom===3.058822
# =========== end of fold 3 in level 0 ===========
# Fold 4/10 , model 0 , custom===3.225208
# Fold 4/10 , model 1 , custom===4.775840
# Fold 4/10 , model 2 , custom===3.227972
# =========== end of fold 4 in level 0 ===========
# Fold 5/10 , model 0 , custom===4.468781
# Fold 5/10 , model 1 , custom===5.235728
# Fold 5/10 , model 2 , custom===3.130948
# =========== end of fold 5 in level 0 ===========
# Fold 6/10 , model 0 , custom===5.014721
# Fold 6/10 , model 1 , custom===6.217104
# Fold 6/10 , model 2 , custom===5.121984
# =========== end of fold 6 in level 0 ===========
# Fold 7/10 , model 0 , custom===3.402285
# Fold 7/10 , model 1 , custom===4.813137
# Fold 7/10 , model 2 , custom===4.360649
# =========== end of fold 7 in level 0 ===========
# Fold 8/10 , model 0 , custom===3.227647
# Fold 8/10 , model 1 , custom===3.799030
# Fold 8/10 , model 2 , custom===2.665124
# =========== end of fold 8 in level 0 ===========
# Fold 9/10 , model 0 , custom===2.715954
# Fold 9/10 , model 1 , custom===3.389045
# Fold 9/10 , model 2 , custom===2.398778
# =========== end of fold 9 in level 0 ===========
# Fold 10/10 , model 0 , custom===3.325298
# Fold 10/10 , model 1 , custom===4.476391
# Fold 10/10 , model 2 , custom===3.163079
# =========== end of fold 10 in level 0 ===========
# Output dimensionality of level 0 is 3
# ====================== End of Level 0 ======================
#  level 0 lasted 119.178239 seconds
# ====================== Start of Level 1 ======================
# Input Dimensionality 3 at Level 1
# 3 models included in Level 1
# Fold 1/10 , model 0 , custom===5.259343
# Fold 1/10 , model 1 , custom===5.238686
# Fold 1/10 , model 2 , custom===5.949564
# =========== end of fold 1 in level 1 ===========
# Fold 2/10 , model 0 , custom===2.785484
# Fold 2/10 , model 1 , custom===2.947761
# Fold 2/10 , model 2 , custom===3.072519
# =========== end of fold 2 in level 1 ===========
# Fold 3/10 , model 0 , custom===3.262145
# Fold 3/10 , model 1 , custom===2.962394
# Fold 3/10 , model 2 , custom===3.227144
# =========== end of fold 3 in level 1 ===========
# Fold 4/10 , model 0 , custom===4.264896
# Fold 4/10 , model 1 , custom===3.066629
# Fold 4/10 , model 2 , custom===2.987990
# =========== end of fold 4 in level 1 ===========
# Fold 5/10 , model 0 , custom===3.734073
# Fold 5/10 , model 1 , custom===4.351380
# Fold 5/10 , model 2 , custom===4.588915
# =========== end of fold 5 in level 1 ===========
# Fold 6/10 , model 0 , custom===5.819524
# Fold 6/10 , model 1 , custom===5.105008
# Fold 6/10 , model 2 , custom===5.193358
# =========== end of fold 6 in level 1 ===========
# Fold 7/10 , model 0 , custom===5.123734
# Fold 7/10 , model 1 , custom===4.705629
# Fold 7/10 , model 2 , custom===5.005370
# =========== end of fold 7 in level 1 ===========
# Fold 8/10 , model 0 , custom===3.415053
# Fold 8/10 , model 1 , custom===2.968655
# Fold 8/10 , model 2 , custom===2.831130
# =========== end of fold 8 in level 1 ===========
# Fold 9/10 , model 0 , custom===2.955297
# Fold 9/10 , model 1 , custom===3.273024
# Fold 9/10 , model 2 , custom===2.837420
# =========== end of fold 9 in level 1 ===========
# Fold 10/10 , model 0 , custom===4.185284
# Fold 10/10 , model 1 , custom===4.080353
# Fold 10/10 , model 2 , custom===3.419387
# =========== end of fold 10 in level 1 ===========
# Output dimensionality of level 1 is 3
# ====================== End of Level 1 ======================
#  level 1 lasted 4.106238 seconds
# ====================== Start of Level 2 ======================
# Input Dimensionality 3 at Level 2
# 1 models included in Level 2
# Fold 1/10 , model 0 , custom===4.746332
# =========== end of fold 1 in level 2 ===========
# Fold 2/10 , model 0 , custom===3.020624
# =========== end of fold 2 in level 2 ===========
# Fold 3/10 , model 0 , custom===2.637416
# =========== end of fold 3 in level 2 ===========
# Fold 4/10 , model 0 , custom===3.087328
# =========== end of fold 4 in level 2 ===========
# Fold 5/10 , model 0 , custom===4.153205
# =========== end of fold 5 in level 2 ===========
# Fold 6/10 , model 0 , custom===5.014012
# =========== end of fold 6 in level 2 ===========
# Fold 7/10 , model 0 , custom===3.660419
# =========== end of fold 7 in level 2 ===========
# Fold 8/10 , model 0 , custom===2.903961
# =========== end of fold 8 in level 2 ===========
# Fold 9/10 , model 0 , custom===2.294689
# =========== end of fold 9 in level 2 ===========
# Fold 10/10 , model 0 , custom===3.473435
# =========== end of fold 10 in level 2 ===========
# Output dimensionality of level 2 is 1
# ====================== End of Level 2 ======================
#  level 2 lasted 4.245704 seconds
# ====================== End of fit ======================
#  fit() lasted 127.530731 seconds
# ====================== Start of Level 0 ======================
# 1 estimators included in Level 0
# ====================== Start of Level 1 ======================
# 1 estimators included in Level 1
# ====================== Start of Level 2 ======================
# 1 estimators included in Level 2
# ====================== Start of Level 0 ======================
# Input Dimensionality 13 at Level 0
# 3 models included in Level 0
# Fold 1/10 , model 0 , custom===3.674465
# Fold 1/10 , model 1 , custom===7.483939
# Fold 1/10 , model 2 , custom===5.574691
# =========== end of fold 1 in level 0 ===========
# Fold 2/10 , model 0 , custom===2.653495
# Fold 2/10 , model 1 , custom===4.214858
# Fold 2/10 , model 2 , custom===2.856961
# =========== end of fold 2 in level 0 ===========
# Fold 3/10 , model 0 , custom===2.427452
# Fold 3/10 , model 1 , custom===3.458628
# Fold 3/10 , model 2 , custom===2.869347
# =========== end of fold 3 in level 0 ===========
# Fold 4/10 , model 0 , custom===3.429627
# Fold 4/10 , model 1 , custom===5.115211
# Fold 4/10 , model 2 , custom===2.970973
# =========== end of fold 4 in level 0 ===========
# Fold 5/10 , model 0 , custom===4.328427
# Fold 5/10 , model 1 , custom===5.418434
# Fold 5/10 , model 2 , custom===2.951151
# =========== end of fold 5 in level 0 ===========
# Fold 6/10 , model 0 , custom===3.066649
# Fold 6/10 , model 1 , custom===6.055622
# Fold 6/10 , model 2 , custom===4.187067
# =========== end of fold 6 in level 0 ===========
# Fold 7/10 , model 0 , custom===3.357571
# Fold 7/10 , model 1 , custom===5.116535
# Fold 7/10 , model 2 , custom===4.382447
# =========== end of fold 7 in level 0 ===========
# Fold 8/10 , model 0 , custom===3.328432
# Fold 8/10 , model 1 , custom===4.072362
# Fold 8/10 , model 2 , custom===2.646659
# =========== end of fold 8 in level 0 ===========
# Fold 9/10 , model 0 , custom===2.923879
# Fold 9/10 , model 1 , custom===3.625595
# Fold 9/10 , model 2 , custom===2.829527
# =========== end of fold 9 in level 0 ===========
# Fold 10/10 , model 0 , custom===3.942129
# Fold 10/10 , model 1 , custom===5.253244
# Fold 10/10 , model 2 , custom===3.825428
# =========== end of fold 10 in level 0 ===========
# Output dimensionality of level 0 is 3
# ====================== End of Level 0 ======================
#  level 0 lasted 133.330360 seconds
# ====================== Start of Level 1 ======================
# Input Dimensionality 3 at Level 1
# 3 models included in Level 1
# Fold 1/10 , model 0 , custom===5.537056
# Fold 1/10 , model 1 , custom===4.587728
# Fold 1/10 , model 2 , custom===4.653619
# =========== end of fold 1 in level 1 ===========
# Fold 2/10 , model 0 , custom===2.766139
# Fold 2/10 , model 1 , custom===3.408608
# Fold 2/10 , model 2 , custom===2.942725
# =========== end of fold 2 in level 1 ===========
# Fold 3/10 , model 0 , custom===3.284030
# Fold 3/10 , model 1 , custom===2.998767
# Fold 3/10 , model 2 , custom===3.046343
# =========== end of fold 3 in level 1 ===========
# Fold 4/10 , model 0 , custom===4.192698
# Fold 4/10 , model 1 , custom===2.801409
# Fold 4/10 , model 2 , custom===2.583309
# =========== end of fold 4 in level 1 ===========
# Fold 5/10 , model 0 , custom===3.531082
# Fold 5/10 , model 1 , custom===5.198744
# Fold 5/10 , model 2 , custom===4.685102
# =========== end of fold 5 in level 1 ===========
# Fold 6/10 , model 0 , custom===5.002531
# Fold 6/10 , model 1 , custom===3.121920
# Fold 6/10 , model 2 , custom===2.983665
# =========== end of fold 6 in level 1 ===========
# Fold 7/10 , model 0 , custom===5.156195
# Fold 7/10 , model 1 , custom===4.849249
# Fold 7/10 , model 2 , custom===4.534303
# =========== end of fold 7 in level 1 ===========
# Fold 8/10 , model 0 , custom===3.433517
# Fold 8/10 , model 1 , custom===3.395605
# Fold 8/10 , model 2 , custom===3.130937
# =========== end of fold 8 in level 1 ===========
# Fold 9/10 , model 0 , custom===3.416632
# Fold 9/10 , model 1 , custom===3.229267
# Fold 9/10 , model 2 , custom===2.670977
# =========== end of fold 9 in level 1 ===========
# Fold 10/10 , model 0 , custom===4.571062
# Fold 10/10 , model 1 , custom===3.517044
# Fold 10/10 , model 2 , custom===3.525694
# =========== end of fold 10 in level 1 ===========
# Output dimensionality of level 1 is 3
# ====================== End of Level 1 ======================
#  level 1 lasted 4.429074 seconds
# ====================== Start of Level 2 ======================
# Input Dimensionality 3 at Level 2
# 1 models included in Level 2
# Fold 1/10 , model 0 , custom===4.965990
# =========== end of fold 1 in level 2 ===========
# Fold 2/10 , model 0 , custom===2.910214
# =========== end of fold 2 in level 2 ===========
# Fold 3/10 , model 0 , custom===2.703822
# =========== end of fold 3 in level 2 ===========
# Fold 4/10 , model 0 , custom===2.769751
# =========== end of fold 4 in level 2 ===========
# Fold 5/10 , model 0 , custom===4.440502
# =========== end of fold 5 in level 2 ===========
# Fold 6/10 , model 0 , custom===3.347711
# =========== end of fold 6 in level 2 ===========
# Fold 7/10 , model 0 , custom===4.035533
# =========== end of fold 7 in level 2 ===========
# Fold 8/10 , model 0 , custom===2.903390
# =========== end of fold 8 in level 2 ===========
# Fold 9/10 , model 0 , custom===2.548792
# =========== end of fold 9 in level 2 ===========
# Fold 10/10 , model 0 , custom===3.753410
# =========== end of fold 10 in level 2 ===========
# Output dimensionality of level 2 is 1
# ====================== End of Level 2 ======================
#  level 2 lasted 4.070825 seconds
# ====================== End of fit ======================
#  fit() lasted 141.832907 seconds
# ====================== Start of Level 0 ======================
# 1 estimators included in Level 0
# ====================== Start of Level 1 ======================
# 1 estimators included in Level 1
# ====================== Start of Level 2 ======================
# 1 estimators included in Level 2
# ====================== Start of Level 0 ======================
# Input Dimensionality 13 at Level 0
# 3 models included in Level 0
# Fold 1/10 , model 0 , custom===4.124555
# Fold 1/10 , model 1 , custom===7.705135
# Fold 1/10 , model 2 , custom===5.666679
# =========== end of fold 1 in level 0 ===========
# Fold 2/10 , model 0 , custom===3.013523
# Fold 2/10 , model 1 , custom===3.858647
# Fold 2/10 , model 2 , custom===2.724388
# =========== end of fold 2 in level 0 ===========
# Fold 3/10 , model 0 , custom===2.479396
# Fold 3/10 , model 1 , custom===3.743807
# Fold 3/10 , model 2 , custom===2.801582
# =========== end of fold 3 in level 0 ===========
# Fold 4/10 , model 0 , custom===3.422669
# Fold 4/10 , model 1 , custom===3.818408
# Fold 4/10 , model 2 , custom===2.265144
# =========== end of fold 4 in level 0 ===========
# Fold 5/10 , model 0 , custom===5.016259
# Fold 5/10 , model 1 , custom===5.801329
# Fold 5/10 , model 2 , custom===3.204026
# =========== end of fold 5 in level 0 ===========
# Fold 6/10 , model 0 , custom===3.422615
# Fold 6/10 , model 1 , custom===6.279948
# Fold 6/10 , model 2 , custom===4.561954
# =========== end of fold 6 in level 0 ===========
# Fold 7/10 , model 0 , custom===3.676677
# Fold 7/10 , model 1 , custom===4.764594
# Fold 7/10 , model 2 , custom===4.954520
# =========== end of fold 7 in level 0 ===========
# Fold 8/10 , model 0 , custom===3.239308
# Fold 8/10 , model 1 , custom===4.155723
# Fold 8/10 , model 2 , custom===2.465304
# =========== end of fold 8 in level 0 ===========
# Fold 9/10 , model 0 , custom===2.852614
# Fold 9/10 , model 1 , custom===3.570052
# Fold 9/10 , model 2 , custom===2.797197
# =========== end of fold 9 in level 0 ===========
# Fold 10/10 , model 0 , custom===3.521678
# Fold 10/10 , model 1 , custom===5.053893
# Fold 10/10 , model 2 , custom===3.758600
# =========== end of fold 10 in level 0 ===========
# Output dimensionality of level 0 is 3
# ====================== End of Level 0 ======================
#  level 0 lasted 105.107096 seconds
# ====================== Start of Level 1 ======================
# Input Dimensionality 3 at Level 1
# 3 models included in Level 1
# Fold 1/10 , model 0 , custom===5.946636
# Fold 1/10 , model 1 , custom===4.421546
# Fold 1/10 , model 2 , custom===4.961025
# =========== end of fold 1 in level 1 ===========
# Fold 2/10 , model 0 , custom===2.833095
# Fold 2/10 , model 1 , custom===3.118257
# Fold 2/10 , model 2 , custom===2.894920
# =========== end of fold 2 in level 1 ===========
# Fold 3/10 , model 0 , custom===3.313026
# Fold 3/10 , model 1 , custom===2.524317
# Fold 3/10 , model 2 , custom===2.716267
# =========== end of fold 3 in level 1 ===========
# Fold 4/10 , model 0 , custom===3.294324
# Fold 4/10 , model 1 , custom===2.700798
# Fold 4/10 , model 2 , custom===2.693336
# =========== end of fold 4 in level 1 ===========
# Fold 5/10 , model 0 , custom===4.239050
# Fold 5/10 , model 1 , custom===4.709534
# Fold 5/10 , model 2 , custom===4.732310
# =========== end of fold 5 in level 1 ===========
# Fold 6/10 , model 0 , custom===5.292332
# Fold 6/10 , model 1 , custom===3.207134
# Fold 6/10 , model 2 , custom===3.629016
# =========== end of fold 6 in level 1 ===========
# Fold 7/10 , model 0 , custom===5.260099
# Fold 7/10 , model 1 , custom===4.939302
# Fold 7/10 , model 2 , custom===4.580000
# =========== end of fold 7 in level 1 ===========
# Fold 8/10 , model 0 , custom===3.355793
# Fold 8/10 , model 1 , custom===2.710103
# Fold 8/10 , model 2 , custom===2.925514
# =========== end of fold 8 in level 1 ===========
# Fold 9/10 , model 0 , custom===3.248371
# Fold 9/10 , model 1 , custom===3.245982
# Fold 9/10 , model 2 , custom===2.837436
# =========== end of fold 9 in level 1 ===========
# Fold 10/10 , model 0 , custom===4.218645
# Fold 10/10 , model 1 , custom===3.489743
# Fold 10/10 , model 2 , custom===3.515884
# =========== end of fold 10 in level 1 ===========
# Output dimensionality of level 1 is 3
# ====================== End of Level 1 ======================
#  level 1 lasted 4.322526 seconds
# ====================== Start of Level 2 ======================
# Input Dimensionality 3 at Level 2
# 1 models included in Level 2
# Fold 1/10 , model 0 , custom===4.937498
# =========== end of fold 1 in level 2 ===========
# Fold 2/10 , model 0 , custom===2.944590
# =========== end of fold 2 in level 2 ===========
# Fold 3/10 , model 0 , custom===2.438759
# =========== end of fold 3 in level 2 ===========
# Fold 4/10 , model 0 , custom===2.475208
# =========== end of fold 4 in level 2 ===========
# Fold 5/10 , model 0 , custom===4.560210
# =========== end of fold 5 in level 2 ===========
# Fold 6/10 , model 0 , custom===3.594999
# =========== end of fold 6 in level 2 ===========
# Fold 7/10 , model 0 , custom===4.595793
# =========== end of fold 7 in level 2 ===========
# Fold 8/10 , model 0 , custom===2.636624
# =========== end of fold 8 in level 2 ===========
# Fold 9/10 , model 0 , custom===2.630926
# =========== end of fold 9 in level 2 ===========
# Fold 10/10 , model 0 , custom===3.613014
# =========== end of fold 10 in level 2 ===========
# Output dimensionality of level 2 is 1
# ====================== End of Level 2 ======================
#  level 2 lasted 4.372125 seconds
# ====================== End of fit ======================
#  fit() lasted 113.802340 seconds
# ====================== Start of Level 0 ======================
# 1 estimators included in Level 0
# ====================== Start of Level 1 ======================
# 1 estimators included in Level 1
# ====================== Start of Level 2 ======================
# 1 estimators included in Level 2
# ====================== Start of Level 0 ======================
# Input Dimensionality 13 at Level 0
# 3 models included in Level 0
# Fold 1/10 , model 0 , custom===3.163912
# Fold 1/10 , model 1 , custom===6.124943
# Fold 1/10 , model 2 , custom===4.292429
# =========== end of fold 1 in level 0 ===========
# Fold 2/10 , model 0 , custom===2.759666
# Fold 2/10 , model 1 , custom===3.851792
# Fold 2/10 , model 2 , custom===2.639682
# =========== end of fold 2 in level 0 ===========
# Fold 3/10 , model 0 , custom===2.408426
# Fold 3/10 , model 1 , custom===3.786789
# Fold 3/10 , model 2 , custom===2.583127
# =========== end of fold 3 in level 0 ===========
# Fold 4/10 , model 0 , custom===3.254962
# Fold 4/10 , model 1 , custom===4.092793
# Fold 4/10 , model 2 , custom===2.376814
# =========== end of fold 4 in level 0 ===========
# Fold 5/10 , model 0 , custom===3.922438
# Fold 5/10 , model 1 , custom===5.567508
# Fold 5/10 , model 2 , custom===3.230820
# =========== end of fold 5 in level 0 ===========
# Fold 6/10 , model 0 , custom===3.771503
# Fold 6/10 , model 1 , custom===5.765065
# Fold 6/10 , model 2 , custom===4.279740
# =========== end of fold 6 in level 0 ===========
# Fold 7/10 , model 0 , custom===3.811111
# Fold 7/10 , model 1 , custom===4.426301
# Fold 7/10 , model 2 , custom===4.379411
# =========== end of fold 7 in level 0 ===========
# Fold 8/10 , model 0 , custom===4.551121
# Fold 8/10 , model 1 , custom===4.557092
# Fold 8/10 , model 2 , custom===3.568256
# =========== end of fold 8 in level 0 ===========
# Fold 9/10 , model 0 , custom===2.511881
# Fold 9/10 , model 1 , custom===3.641508
# Fold 9/10 , model 2 , custom===2.440903
# =========== end of fold 9 in level 0 ===========
# Fold 10/10 , model 0 , custom===3.525765
# Fold 10/10 , model 1 , custom===5.278830
# Fold 10/10 , model 2 , custom===3.832266
# =========== end of fold 10 in level 0 ===========
# Output dimensionality of level 0 is 3
# ====================== End of Level 0 ======================
#  level 0 lasted 62.695907 seconds
# ====================== Start of Level 1 ======================
# Input Dimensionality 3 at Level 1
# 3 models included in Level 1
# Fold 1/10 , model 0 , custom===4.630118
# Fold 1/10 , model 1 , custom===3.598954
# Fold 1/10 , model 2 , custom===3.316041
# =========== end of fold 1 in level 1 ===========
# Fold 2/10 , model 0 , custom===2.780361
# Fold 2/10 , model 1 , custom===2.948845
# Fold 2/10 , model 2 , custom===3.021014
# =========== end of fold 2 in level 1 ===========
# Fold 3/10 , model 0 , custom===3.063639
# Fold 3/10 , model 1 , custom===2.838691
# Fold 3/10 , model 2 , custom===2.639112
# =========== end of fold 3 in level 1 ===========
# Fold 4/10 , model 0 , custom===3.426492
# Fold 4/10 , model 1 , custom===2.728512
# Fold 4/10 , model 2 , custom===2.562449
# =========== end of fold 4 in level 1 ===========
# Fold 5/10 , model 0 , custom===4.116713
# Fold 5/10 , model 1 , custom===3.633432
# Fold 5/10 , model 2 , custom===3.552511
# =========== end of fold 5 in level 1 ===========
# Fold 6/10 , model 0 , custom===4.818413
# Fold 6/10 , model 1 , custom===4.576131
# Fold 6/10 , model 2 , custom===3.623979
# =========== end of fold 6 in level 1 ===========
# Fold 7/10 , model 0 , custom===4.999775
# Fold 7/10 , model 1 , custom===3.588170
# Fold 7/10 , model 2 , custom===3.898403
# =========== end of fold 7 in level 1 ===========
# Fold 8/10 , model 0 , custom===4.562606
# Fold 8/10 , model 1 , custom===3.994746
# Fold 8/10 , model 2 , custom===3.966182
# =========== end of fold 8 in level 1 ===========
# Fold 9/10 , model 0 , custom===3.050604
# Fold 9/10 , model 1 , custom===3.254689
# Fold 9/10 , model 2 , custom===2.801138
# =========== end of fold 9 in level 1 ===========
# Fold 10/10 , model 0 , custom===4.377358
# Fold 10/10 , model 1 , custom===3.253777
# Fold 10/10 , model 2 , custom===3.629442
# =========== end of fold 10 in level 1 ===========
# Output dimensionality of level 1 is 3
# ====================== End of Level 1 ======================
#  level 1 lasted 4.354584 seconds
# ====================== Start of Level 2 ======================
# Input Dimensionality 3 at Level 2
# 1 models included in Level 2
# Fold 1/10 , model 0 , custom===3.551156
# =========== end of fold 1 in level 2 ===========
# Fold 2/10 , model 0 , custom===2.796484
# =========== end of fold 2 in level 2 ===========
# Fold 3/10 , model 0 , custom===2.570291
# =========== end of fold 3 in level 2 ===========
# Fold 4/10 , model 0 , custom===2.397255
# =========== end of fold 4 in level 2 ===========
# Fold 5/10 , model 0 , custom===3.548538
# =========== end of fold 5 in level 2 ===========
# Fold 6/10 , model 0 , custom===3.939978
# =========== end of fold 6 in level 2 ===========
# Fold 7/10 , model 0 , custom===3.735615
# =========== end of fold 7 in level 2 ===========
# Fold 8/10 , model 0 , custom===3.857127
# =========== end of fold 8 in level 2 ===========
# Fold 9/10 , model 0 , custom===2.526305
# =========== end of fold 9 in level 2 ===========
# Fold 10/10 , model 0 , custom===3.547965
# =========== end of fold 10 in level 2 ===========
# Output dimensionality of level 2 is 1
# ====================== End of Level 2 ======================
#  level 2 lasted 4.289241 seconds
# ====================== End of fit ======================
#  fit() lasted 71.340513 seconds
# ====================== Start of Level 0 ======================
# 1 estimators included in Level 0
# ====================== Start of Level 1 ======================
# 1 estimators included in Level 1
# ====================== Start of Level 2 ======================
# 1 estimators included in Level 2
# ====================== Start of Level 0 ======================
# Input Dimensionality 13 at Level 0
# 3 models included in Level 0
# Fold 1/10 , model 0 , custom===2.911275
# Fold 1/10 , model 1 , custom===5.994041
# Fold 1/10 , model 2 , custom===3.576688
# =========== end of fold 1 in level 0 ===========
# Fold 2/10 , model 0 , custom===2.806807
# Fold 2/10 , model 1 , custom===3.852887
# Fold 2/10 , model 2 , custom===2.762339
# =========== end of fold 2 in level 0 ===========
# Fold 3/10 , model 0 , custom===4.728535
# Fold 3/10 , model 1 , custom===4.370151
# Fold 3/10 , model 2 , custom===2.754861
# =========== end of fold 3 in level 0 ===========
# Fold 4/10 , model 0 , custom===2.647970
# Fold 4/10 , model 1 , custom===4.632112
# Fold 4/10 , model 2 , custom===2.298728
# =========== end of fold 4 in level 0 ===========
# Fold 5/10 , model 0 , custom===3.981719
# Fold 5/10 , model 1 , custom===6.844049
# Fold 5/10 , model 2 , custom===4.288598
# =========== end of fold 5 in level 0 ===========
# Fold 6/10 , model 0 , custom===3.410178
# Fold 6/10 , model 1 , custom===6.019198
# Fold 6/10 , model 2 , custom===3.961093
# =========== end of fold 6 in level 0 ===========
# Fold 7/10 , model 0 , custom===2.772596
# Fold 7/10 , model 1 , custom===4.192940
# Fold 7/10 , model 2 , custom===4.397144
# =========== end of fold 7 in level 0 ===========
# Fold 8/10 , model 0 , custom===2.732144
# Fold 8/10 , model 1 , custom===4.444034
# Fold 8/10 , model 2 , custom===3.315493
# =========== end of fold 8 in level 0 ===========
# Fold 9/10 , model 0 , custom===2.261481
# Fold 9/10 , model 1 , custom===4.019135
# Fold 9/10 , model 2 , custom===2.364505
# =========== end of fold 9 in level 0 ===========
# Fold 10/10 , model 0 , custom===3.427358
# Fold 10/10 , model 1 , custom===5.388181
# Fold 10/10 , model 2 , custom===4.027059
# =========== end of fold 10 in level 0 ===========
# Output dimensionality of level 0 is 3
# ====================== End of Level 0 ======================
#  level 0 lasted 152.991434 seconds
# ====================== Start of Level 1 ======================
# Input Dimensionality 3 at Level 1
# 3 models included in Level 1
# Fold 1/10 , model 0 , custom===4.447866
# Fold 1/10 , model 1 , custom===2.933345
# Fold 1/10 , model 2 , custom===3.941429
# =========== end of fold 1 in level 1 ===========
# Fold 2/10 , model 0 , custom===2.955089
# Fold 2/10 , model 1 , custom===3.157232
# Fold 2/10 , model 2 , custom===2.934999
# =========== end of fold 2 in level 1 ===========
# Fold 3/10 , model 0 , custom===3.764047
# Fold 3/10 , model 1 , custom===5.242257
# Fold 3/10 , model 2 , custom===4.862673
# =========== end of fold 3 in level 1 ===========
# Fold 4/10 , model 0 , custom===3.627738
# Fold 4/10 , model 1 , custom===2.397458
# Fold 4/10 , model 2 , custom===2.649190
# =========== end of fold 4 in level 1 ===========
# Fold 5/10 , model 0 , custom===5.239192
# Fold 5/10 , model 1 , custom===3.495352
# Fold 5/10 , model 2 , custom===3.407222
# =========== end of fold 5 in level 1 ===========
# Fold 6/10 , model 0 , custom===4.791232
# Fold 6/10 , model 1 , custom===3.035385
# Fold 6/10 , model 2 , custom===3.015001
# =========== end of fold 6 in level 1 ===========
# Fold 7/10 , model 0 , custom===4.268050
# Fold 7/10 , model 1 , custom===3.936245
# Fold 7/10 , model 2 , custom===4.137714
# =========== end of fold 7 in level 1 ===========
# Fold 8/10 , model 0 , custom===3.504201
# Fold 8/10 , model 1 , custom===3.317881
# Fold 8/10 , model 2 , custom===3.047585
# =========== end of fold 8 in level 1 ===========
# Fold 9/10 , model 0 , custom===2.962856
# Fold 9/10 , model 1 , custom===2.829225
# Fold 9/10 , model 2 , custom===2.429530
# =========== end of fold 9 in level 1 ===========
# Fold 10/10 , model 0 , custom===4.432317
# Fold 10/10 , model 1 , custom===3.839795
# Fold 10/10 , model 2 , custom===3.480823
# =========== end of fold 10 in level 1 ===========
# Output dimensionality of level 1 is 3
# ====================== End of Level 1 ======================
#  level 1 lasted 4.616134 seconds
# ====================== Start of Level 2 ======================
# Input Dimensionality 3 at Level 2
# 1 models included in Level 2
# Fold 1/10 , model 0 , custom===3.212312
# =========== end of fold 1 in level 2 ===========
# Fold 2/10 , model 0 , custom===2.855398
# =========== end of fold 2 in level 2 ===========
# Fold 3/10 , model 0 , custom===4.643757
# =========== end of fold 3 in level 2 ===========
# Fold 4/10 , model 0 , custom===2.451672
# =========== end of fold 4 in level 2 ===========
# Fold 5/10 , model 0 , custom===3.904524
# =========== end of fold 5 in level 2 ===========
# Fold 6/10 , model 0 , custom===3.424855
# =========== end of fold 6 in level 2 ===========
# Fold 7/10 , model 0 , custom===3.601075
# =========== end of fold 7 in level 2 ===========
# Fold 8/10 , model 0 , custom===2.952473
# =========== end of fold 8 in level 2 ===========
# Fold 9/10 , model 0 , custom===2.342939
# =========== end of fold 9 in level 2 ===========
# Fold 10/10 , model 0 , custom===3.574453
# =========== end of fold 10 in level 2 ===========
# Output dimensionality of level 2 is 1
# ====================== End of Level 2 ======================
#  level 2 lasted 4.428935 seconds
# ====================== End of fit ======================
#  fit() lasted 162.037306 seconds
# ====================== Start of Level 0 ======================
# 1 estimators included in Level 0
# ====================== Start of Level 1 ======================
# 1 estimators included in Level 1
# ====================== Start of Level 2 ======================
# 1 estimators included in Level 2
# ====================== Start of Level 0 ======================
# Input Dimensionality 13 at Level 0
# 3 models included in Level 0
# Fold 1/10 , model 0 , custom===2.595892
# Fold 1/10 , model 1 , custom===5.560950
# Fold 1/10 , model 2 , custom===3.497438
# =========== end of fold 1 in level 0 ===========
# Fold 2/10 , model 0 , custom===2.597480
# Fold 2/10 , model 1 , custom===3.960238
# Fold 2/10 , model 2 , custom===2.583975
# =========== end of fold 2 in level 0 ===========
# Fold 3/10 , model 0 , custom===4.978665
# Fold 3/10 , model 1 , custom===4.656291
# Fold 3/10 , model 2 , custom===3.046633
# =========== end of fold 3 in level 0 ===========
# Fold 4/10 , model 0 , custom===2.959359
# Fold 4/10 , model 1 , custom===4.828208
# Fold 4/10 , model 2 , custom===2.908432
# =========== end of fold 4 in level 0 ===========
# Fold 5/10 , model 0 , custom===4.601909
# Fold 5/10 , model 1 , custom===6.596757
# Fold 5/10 , model 2 , custom===3.910417
# =========== end of fold 5 in level 0 ===========
# Fold 6/10 , model 0 , custom===3.393147
# Fold 6/10 , model 1 , custom===5.727082
# Fold 6/10 , model 2 , custom===3.856140
# =========== end of fold 6 in level 0 ===========
# Fold 7/10 , model 0 , custom===2.159628
# Fold 7/10 , model 1 , custom===3.717978
# Fold 7/10 , model 2 , custom===2.850319
# =========== end of fold 7 in level 0 ===========
# Fold 8/10 , model 0 , custom===2.637633
# Fold 8/10 , model 1 , custom===4.226872
# Fold 8/10 , model 2 , custom===2.332940
# =========== end of fold 8 in level 0 ===========
# Fold 9/10 , model 0 , custom===3.598816
# Fold 9/10 , model 1 , custom===4.648398
# Fold 9/10 , model 2 , custom===2.527383
# =========== end of fold 9 in level 0 ===========
# Fold 10/10 , model 0 , custom===3.766139
# Fold 10/10 , model 1 , custom===4.755866
# Fold 10/10 , model 2 , custom===3.459051
# =========== end of fold 10 in level 0 ===========
# Output dimensionality of level 0 is 3
# ====================== End of Level 0 ======================
#  level 0 lasted 147.834506 seconds
# ====================== Start of Level 1 ======================
# Input Dimensionality 3 at Level 1
# 3 models included in Level 1
# Fold 1/10 , model 0 , custom===4.218699
# Fold 1/10 , model 1 , custom===2.974684
# Fold 1/10 , model 2 , custom===2.559722
# =========== end of fold 1 in level 1 ===========
# Fold 2/10 , model 0 , custom===3.037961
# Fold 2/10 , model 1 , custom===3.226000
# Fold 2/10 , model 2 , custom===3.200080
# =========== end of fold 2 in level 1 ===========
# Fold 3/10 , model 0 , custom===4.099820
# Fold 3/10 , model 1 , custom===4.196006
# Fold 3/10 , model 2 , custom===4.232893
# =========== end of fold 3 in level 1 ===========
# Fold 4/10 , model 0 , custom===4.165304
# Fold 4/10 , model 1 , custom===2.709933
# Fold 4/10 , model 2 , custom===2.692026
# =========== end of fold 4 in level 1 ===========
# Fold 5/10 , model 0 , custom===5.251853
# Fold 5/10 , model 1 , custom===3.970313
# Fold 5/10 , model 2 , custom===3.851077
# =========== end of fold 5 in level 1 ===========
# Fold 6/10 , model 0 , custom===4.658130
# Fold 6/10 , model 1 , custom===3.121618
# Fold 6/10 , model 2 , custom===3.114137
# =========== end of fold 6 in level 1 ===========
# Fold 7/10 , model 0 , custom===3.017910
# Fold 7/10 , model 1 , custom===3.180282
# Fold 7/10 , model 2 , custom===3.032082
# =========== end of fold 7 in level 1 ===========
# Fold 8/10 , model 0 , custom===3.215657
# Fold 8/10 , model 1 , custom===2.704518
# Fold 8/10 , model 2 , custom===2.530573
# =========== end of fold 8 in level 1 ===========
# Fold 9/10 , model 0 , custom===3.808301
# Fold 9/10 , model 1 , custom===3.766085
# Fold 9/10 , model 2 , custom===3.722333
# =========== end of fold 9 in level 1 ===========
# Fold 10/10 , model 0 , custom===3.845290
# Fold 10/10 , model 1 , custom===3.511087
# Fold 10/10 , model 2 , custom===3.205312
# =========== end of fold 10 in level 1 ===========
# Output dimensionality of level 1 is 3
# ====================== End of Level 1 ======================
#  level 1 lasted 4.916254 seconds
# ====================== Start of Level 2 ======================
# Input Dimensionality 3 at Level 2
# 1 models included in Level 2
# Fold 1/10 , model 0 , custom===2.836037
# =========== end of fold 1 in level 2 ===========
# Fold 2/10 , model 0 , custom===2.795753
# =========== end of fold 2 in level 2 ===========
# Fold 3/10 , model 0 , custom===4.121862
# =========== end of fold 3 in level 2 ===========
# Fold 4/10 , model 0 , custom===2.699050
# =========== end of fold 4 in level 2 ===========
# Fold 5/10 , model 0 , custom===4.128788
# =========== end of fold 5 in level 2 ===========
# Fold 6/10 , model 0 , custom===3.352552
# =========== end of fold 6 in level 2 ===========
# Fold 7/10 , model 0 , custom===2.759908
# =========== end of fold 7 in level 2 ===========
# Fold 8/10 , model 0 , custom===2.424682
# =========== end of fold 8 in level 2 ===========
# Fold 9/10 , model 0 , custom===3.413316
# =========== end of fold 9 in level 2 ===========
# Fold 10/10 , model 0 , custom===3.244326
# =========== end of fold 10 in level 2 ===========
# Output dimensionality of level 2 is 1
# ====================== End of Level 2 ======================
#  level 2 lasted 4.544532 seconds
# ====================== End of fit ======================
#  fit() lasted 157.295935 seconds
# ====================== Start of Level 0 ======================
# 1 estimators included in Level 0
# ====================== Start of Level 1 ======================
# 1 estimators included in Level 1
# ====================== Start of Level 2 ======================
# 1 estimators included in Level 2
# ====================== Start of Level 0 ======================
# Input Dimensionality 13 at Level 0
# 3 models included in Level 0
# Fold 1/10 , model 0 , custom===3.335637
# Fold 1/10 , model 1 , custom===5.477278
# Fold 1/10 , model 2 , custom===3.834992
# =========== end of fold 1 in level 0 ===========
# Fold 2/10 , model 0 , custom===3.027306
# Fold 2/10 , model 1 , custom===4.090371
# Fold 2/10 , model 2 , custom===3.068077
# =========== end of fold 2 in level 0 ===========
# Fold 3/10 , model 0 , custom===5.049048
# Fold 3/10 , model 1 , custom===4.455265
# Fold 3/10 , model 2 , custom===2.689722
# =========== end of fold 3 in level 0 ===========
# Fold 4/10 , model 0 , custom===2.696357
# Fold 4/10 , model 1 , custom===4.717476
# Fold 4/10 , model 2 , custom===2.933995
# =========== end of fold 4 in level 0 ===========
# Fold 5/10 , model 0 , custom===4.615142
# Fold 5/10 , model 1 , custom===6.930929
# Fold 5/10 , model 2 , custom===5.107854
# =========== end of fold 5 in level 0 ===========
# Fold 6/10 , model 0 , custom===3.612204
# Fold 6/10 , model 1 , custom===5.939272
# Fold 6/10 , model 2 , custom===4.810693
# =========== end of fold 6 in level 0 ===========
# Fold 7/10 , model 0 , custom===2.453839
# Fold 7/10 , model 1 , custom===3.536039
# Fold 7/10 , model 2 , custom===2.721557
# =========== end of fold 7 in level 0 ===========
# Fold 8/10 , model 0 , custom===2.203565
# Fold 8/10 , model 1 , custom===4.494766
# Fold 8/10 , model 2 , custom===2.431079
# =========== end of fold 8 in level 0 ===========
# Fold 9/10 , model 0 , custom===3.486819
# Fold 9/10 , model 1 , custom===4.842240
# Fold 9/10 , model 2 , custom===2.776954
# =========== end of fold 9 in level 0 ===========
# Fold 10/10 , model 0 , custom===3.586948
# Fold 10/10 , model 1 , custom===4.997185
# Fold 10/10 , model 2 , custom===3.535265
# =========== end of fold 10 in level 0 ===========
# Output dimensionality of level 0 is 3
# ====================== End of Level 0 ======================
#  level 0 lasted 133.771434 seconds
# ====================== Start of Level 1 ======================
# Input Dimensionality 3 at Level 1
# 3 models included in Level 1
# Fold 1/10 , model 0 , custom===4.597910
# Fold 1/10 , model 1 , custom===3.337817
# Fold 1/10 , model 2 , custom===3.548870
# =========== end of fold 1 in level 1 ===========
# Fold 2/10 , model 0 , custom===3.024282
# Fold 2/10 , model 1 , custom===3.773236
# Fold 2/10 , model 2 , custom===3.246319
# =========== end of fold 2 in level 1 ===========
# Fold 3/10 , model 0 , custom===3.792327
# Fold 3/10 , model 1 , custom===4.481883
# Fold 3/10 , model 2 , custom===4.568109
# =========== end of fold 3 in level 1 ===========
# Fold 4/10 , model 0 , custom===4.207292
# Fold 4/10 , model 1 , custom===2.476294
# Fold 4/10 , model 2 , custom===2.257187
# =========== end of fold 4 in level 1 ===========
# Fold 5/10 , model 0 , custom===5.785021
# Fold 5/10 , model 1 , custom===4.326220
# Fold 5/10 , model 2 , custom===4.096095
# =========== end of fold 5 in level 1 ===========
# Fold 6/10 , model 0 , custom===4.890062
# Fold 6/10 , model 1 , custom===3.934046
# Fold 6/10 , model 2 , custom===3.960173
# =========== end of fold 6 in level 1 ===========
# Fold 7/10 , model 0 , custom===2.924537
# Fold 7/10 , model 1 , custom===3.117777
# Fold 7/10 , model 2 , custom===2.557212
# =========== end of fold 7 in level 1 ===========
# Fold 8/10 , model 0 , custom===3.337310
# Fold 8/10 , model 1 , custom===2.282507
# Fold 8/10 , model 2 , custom===2.115388
# =========== end of fold 8 in level 1 ===========
# Fold 9/10 , model 0 , custom===3.944140
# Fold 9/10 , model 1 , custom===3.487633
# Fold 9/10 , model 2 , custom===3.177442
# =========== end of fold 9 in level 1 ===========
# Fold 10/10 , model 0 , custom===4.135136
# Fold 10/10 , model 1 , custom===3.414205
# Fold 10/10 , model 2 , custom===3.085677
# =========== end of fold 10 in level 1 ===========
# Output dimensionality of level 1 is 3
# ====================== End of Level 1 ======================
#  level 1 lasted 4.274445 seconds
# ====================== Start of Level 2 ======================
# Input Dimensionality 3 at Level 2
# 1 models included in Level 2
# Fold 1/10 , model 0 , custom===3.611385
# =========== end of fold 1 in level 2 ===========
# Fold 2/10 , model 0 , custom===3.188989
# =========== end of fold 2 in level 2 ===========
# Fold 3/10 , model 0 , custom===4.521355
# =========== end of fold 3 in level 2 ===========
# Fold 4/10 , model 0 , custom===2.272696
# =========== end of fold 4 in level 2 ===========
# Fold 5/10 , model 0 , custom===4.294403
# =========== end of fold 5 in level 2 ===========
# Fold 6/10 , model 0 , custom===4.021044
# =========== end of fold 6 in level 2 ===========
# Fold 7/10 , model 0 , custom===2.629284
# =========== end of fold 7 in level 2 ===========
# Fold 8/10 , model 0 , custom===2.098580
# =========== end of fold 8 in level 2 ===========
# Fold 9/10 , model 0 , custom===3.094353
# =========== end of fold 9 in level 2 ===========
# Fold 10/10 , model 0 , custom===3.037745
# =========== end of fold 10 in level 2 ===========
# Output dimensionality of level 2 is 1
# ====================== End of Level 2 ======================
#  level 2 lasted 4.306765 seconds
# ====================== End of fit ======================
#  fit() lasted 142.353652 seconds
# ====================== Start of Level 0 ======================
# 1 estimators included in Level 0
# ====================== Start of Level 1 ======================
# 1 estimators included in Level 1
# ====================== Start of Level 2 ======================
# 1 estimators included in Level 2
# ====================== Start of Level 0 ======================
# Input Dimensionality 13 at Level 0
# 3 models included in Level 0
# Fold 1/10 , model 0 , custom===3.003536
# Fold 1/10 , model 1 , custom===5.117587
# Fold 1/10 , model 2 , custom===3.440513
# =========== end of fold 1 in level 0 ===========
# Fold 2/10 , model 0 , custom===3.113247
# Fold 2/10 , model 1 , custom===3.988969
# Fold 2/10 , model 2 , custom===2.878485
# =========== end of fold 2 in level 0 ===========
# Fold 3/10 , model 0 , custom===4.577167
# Fold 3/10 , model 1 , custom===4.302408
# Fold 3/10 , model 2 , custom===2.677140
# =========== end of fold 3 in level 0 ===========
# Fold 4/10 , model 0 , custom===2.500561
# Fold 4/10 , model 1 , custom===4.559691
# Fold 4/10 , model 2 , custom===3.032006
# =========== end of fold 4 in level 0 ===========
# Fold 5/10 , model 0 , custom===5.063257
# Fold 5/10 , model 1 , custom===7.172353
# Fold 5/10 , model 2 , custom===5.103030
# =========== end of fold 5 in level 0 ===========
# Fold 6/10 , model 0 , custom===3.283269
# Fold 6/10 , model 1 , custom===5.820998
# Fold 6/10 , model 2 , custom===3.685655
# =========== end of fold 6 in level 0 ===========
# Fold 7/10 , model 0 , custom===2.662433
# Fold 7/10 , model 1 , custom===3.848173
# Fold 7/10 , model 2 , custom===2.869420
# =========== end of fold 7 in level 0 ===========
# Fold 8/10 , model 0 , custom===2.094252
# Fold 8/10 , model 1 , custom===4.832293
# Fold 8/10 , model 2 , custom===2.568746
# =========== end of fold 8 in level 0 ===========
# Fold 9/10 , model 0 , custom===3.727046
# Fold 9/10 , model 1 , custom===4.820856
# Fold 9/10 , model 2 , custom===2.751941
# =========== end of fold 9 in level 0 ===========
# Fold 10/10 , model 0 , custom===3.815583
# Fold 10/10 , model 1 , custom===5.051504
# Fold 10/10 , model 2 , custom===3.648350
# =========== end of fold 10 in level 0 ===========
# Output dimensionality of level 0 is 3
# ====================== End of Level 0 ======================
#  level 0 lasted 126.321127 seconds
# ====================== Start of Level 1 ======================
# Input Dimensionality 3 at Level 1
# 3 models included in Level 1
# Fold 1/10 , model 0 , custom===3.983320
# Fold 1/10 , model 1 , custom===2.632360
# Fold 1/10 , model 2 , custom===2.341683
# =========== end of fold 1 in level 1 ===========
# Fold 2/10 , model 0 , custom===2.975437
# Fold 2/10 , model 1 , custom===3.561607
# Fold 2/10 , model 2 , custom===3.818800
# =========== end of fold 2 in level 1 ===========
# Fold 3/10 , model 0 , custom===3.724134
# Fold 3/10 , model 1 , custom===4.673514
# Fold 3/10 , model 2 , custom===4.132923
# =========== end of fold 3 in level 1 ===========
# Fold 4/10 , model 0 , custom===4.083171
# Fold 4/10 , model 1 , custom===2.686906
# Fold 4/10 , model 2 , custom===2.637524
# =========== end of fold 4 in level 1 ===========
# Fold 5/10 , model 0 , custom===5.917359
# Fold 5/10 , model 1 , custom===5.911088
# Fold 5/10 , model 2 , custom===5.440888
# =========== end of fold 5 in level 1 ===========
# Fold 6/10 , model 0 , custom===4.496323
# Fold 6/10 , model 1 , custom===3.530189
# Fold 6/10 , model 2 , custom===2.954289
# =========== end of fold 6 in level 1 ===========
# Fold 7/10 , model 0 , custom===3.186528
# Fold 7/10 , model 1 , custom===3.081818
# Fold 7/10 , model 2 , custom===2.825547
# =========== end of fold 7 in level 1 ===========
# Fold 8/10 , model 0 , custom===3.572674
# Fold 8/10 , model 1 , custom===2.051937
# Fold 8/10 , model 2 , custom===2.295666
# =========== end of fold 8 in level 1 ===========
# Fold 9/10 , model 0 , custom===4.008953
# Fold 9/10 , model 1 , custom===3.500099
# Fold 9/10 , model 2 , custom===3.540976
# =========== end of fold 9 in level 1 ===========
# Fold 10/10 , model 0 , custom===4.268376
# Fold 10/10 , model 1 , custom===3.917008
# Fold 10/10 , model 2 , custom===3.389422
# =========== end of fold 10 in level 1 ===========
# Output dimensionality of level 1 is 3
# ====================== End of Level 1 ======================
#  level 1 lasted 4.514398 seconds
# ====================== Start of Level 2 ======================
# Input Dimensionality 3 at Level 2
# 1 models included in Level 2
# Fold 1/10 , model 0 , custom===2.822751
# =========== end of fold 1 in level 2 ===========
# Fold 2/10 , model 0 , custom===3.293680
# =========== end of fold 2 in level 2 ===========
# Fold 3/10 , model 0 , custom===4.016354
# =========== end of fold 3 in level 2 ===========
# Fold 4/10 , model 0 , custom===2.588322
# =========== end of fold 4 in level 2 ===========
# Fold 5/10 , model 0 , custom===5.226245
# =========== end of fold 5 in level 2 ===========
# Fold 6/10 , model 0 , custom===3.358738
# =========== end of fold 6 in level 2 ===========
# Fold 7/10 , model 0 , custom===2.777205
# =========== end of fold 7 in level 2 ===========
# Fold 8/10 , model 0 , custom===2.243874
# =========== end of fold 8 in level 2 ===========
# Fold 9/10 , model 0 , custom===3.268577
# =========== end of fold 9 in level 2 ===========
# Fold 10/10 , model 0 , custom===3.309818
# =========== end of fold 10 in level 2 ===========
# Output dimensionality of level 2 is 1
# ====================== End of Level 2 ======================
#  level 2 lasted 4.398995 seconds
# ====================== End of fit ======================
#  fit() lasted 135.235135 seconds
# ====================== Start of Level 0 ======================
# 1 estimators included in Level 0
# ====================== Start of Level 1 ======================
# 1 estimators included in Level 1
# ====================== Start of Level 2 ======================
# 1 estimators included in Level 2
# ====================== Start of Level 0 ======================
# Input Dimensionality 13 at Level 0
# 3 models included in Level 0
# Fold 1/10 , model 0 , custom===4.715888
# Fold 1/10 , model 1 , custom===5.293446
# Fold 1/10 , model 2 , custom===4.534604
# =========== end of fold 1 in level 0 ===========
# Fold 2/10 , model 0 , custom===2.684008
# Fold 2/10 , model 1 , custom===2.771786
# Fold 2/10 , model 2 , custom===2.723575
# =========== end of fold 2 in level 0 ===========
# Fold 3/10 , model 0 , custom===4.523356
# Fold 3/10 , model 1 , custom===4.296880
# Fold 3/10 , model 2 , custom===2.615705
# =========== end of fold 3 in level 0 ===========
# Fold 4/10 , model 0 , custom===2.969597
# Fold 4/10 , model 1 , custom===4.340736
# Fold 4/10 , model 2 , custom===3.352516
# =========== end of fold 4 in level 0 ===========
# Fold 5/10 , model 0 , custom===4.778472
# Fold 5/10 , model 1 , custom===7.032370
# Fold 5/10 , model 2 , custom===5.024373
# =========== end of fold 5 in level 0 ===========
# Fold 6/10 , model 0 , custom===2.909357
# Fold 6/10 , model 1 , custom===4.639648
# Fold 6/10 , model 2 , custom===2.899871
# =========== end of fold 6 in level 0 ===========
# Fold 7/10 , model 0 , custom===2.627274
# Fold 7/10 , model 1 , custom===3.949347
# Fold 7/10 , model 2 , custom===2.882348
# =========== end of fold 7 in level 0 ===========
# Fold 8/10 , model 0 , custom===2.604371
# Fold 8/10 , model 1 , custom===5.295735
# Fold 8/10 , model 2 , custom===2.863229
# =========== end of fold 8 in level 0 ===========
# Fold 9/10 , model 0 , custom===3.504451
# Fold 9/10 , model 1 , custom===5.079887
# Fold 9/10 , model 2 , custom===2.655461
# =========== end of fold 9 in level 0 ===========
# Fold 10/10 , model 0 , custom===3.561891
# Fold 10/10 , model 1 , custom===5.363529
# Fold 10/10 , model 2 , custom===3.841354
# =========== end of fold 10 in level 0 ===========
# Output dimensionality of level 0 is 3
# ====================== End of Level 0 ======================
#  level 0 lasted 119.625668 seconds
# ====================== Start of Level 1 ======================
# Input Dimensionality 3 at Level 1
# 3 models included in Level 1
# Fold 1/10 , model 0 , custom===5.090122
# Fold 1/10 , model 1 , custom===4.647093
# Fold 1/10 , model 2 , custom===4.353983
# =========== end of fold 1 in level 1 ===========
# Fold 2/10 , model 0 , custom===2.457358
# Fold 2/10 , model 1 , custom===3.483618
# Fold 2/10 , model 2 , custom===3.312298
# =========== end of fold 2 in level 1 ===========
# Fold 3/10 , model 0 , custom===3.680480
# Fold 3/10 , model 1 , custom===4.372048
# Fold 3/10 , model 2 , custom===4.068772
# =========== end of fold 3 in level 1 ===========
# Fold 4/10 , model 0 , custom===4.004892
# Fold 4/10 , model 1 , custom===2.913680
# Fold 4/10 , model 2 , custom===2.685360
# =========== end of fold 4 in level 1 ===========
# Fold 5/10 , model 0 , custom===5.910842
# Fold 5/10 , model 1 , custom===5.421211
# Fold 5/10 , model 2 , custom===4.912632
# =========== end of fold 5 in level 1 ===========
# Fold 6/10 , model 0 , custom===3.463761
# Fold 6/10 , model 1 , custom===2.957840
# Fold 6/10 , model 2 , custom===2.558930
# =========== end of fold 6 in level 1 ===========
# Fold 7/10 , model 0 , custom===3.140182
# Fold 7/10 , model 1 , custom===3.486640
# Fold 7/10 , model 2 , custom===2.781143
# =========== end of fold 7 in level 1 ===========
# Fold 8/10 , model 0 , custom===4.152054
# Fold 8/10 , model 1 , custom===2.433269
# Fold 8/10 , model 2 , custom===2.433396
# =========== end of fold 8 in level 1 ===========
# Fold 9/10 , model 0 , custom===4.148301
# Fold 9/10 , model 1 , custom===3.274727
# Fold 9/10 , model 2 , custom===3.166724
# =========== end of fold 9 in level 1 ===========
# Fold 10/10 , model 0 , custom===4.390195
# Fold 10/10 , model 1 , custom===4.082153
# Fold 10/10 , model 2 , custom===3.791429
# =========== end of fold 10 in level 1 ===========
# Output dimensionality of level 1 is 3
# ====================== End of Level 1 ======================
#  level 1 lasted 4.346576 seconds
# ====================== Start of Level 2 ======================
# Input Dimensionality 3 at Level 2
# 1 models included in Level 2
# Fold 1/10 , model 0 , custom===4.429068
# =========== end of fold 1 in level 2 ===========
# Fold 2/10 , model 0 , custom===3.044856
# =========== end of fold 2 in level 2 ===========
# Fold 3/10 , model 0 , custom===3.839822
# =========== end of fold 3 in level 2 ===========
# Fold 4/10 , model 0 , custom===2.616489
# =========== end of fold 4 in level 2 ===========
# Fold 5/10 , model 0 , custom===5.011732
# =========== end of fold 5 in level 2 ===========
# Fold 6/10 , model 0 , custom===2.766632
# =========== end of fold 6 in level 2 ===========
# Fold 7/10 , model 0 , custom===2.680217
# =========== end of fold 7 in level 2 ===========
# Fold 8/10 , model 0 , custom===2.742044
# =========== end of fold 8 in level 2 ===========
# Fold 9/10 , model 0 , custom===2.997821
# =========== end of fold 9 in level 2 ===========
# Fold 10/10 , model 0 , custom===3.462720
# =========== end of fold 10 in level 2 ===========
# Output dimensionality of level 2 is 1
# ====================== End of Level 2 ======================
#  level 2 lasted 4.424340 seconds
# ====================== End of fit ======================
#  fit() lasted 128.397161 seconds
# ====================== Start of Level 0 ======================
# 1 estimators included in Level 0
# ====================== Start of Level 1 ======================
# 1 estimators included in Level 1
# ====================== Start of Level 2 ======================
# 1 estimators included in Level 2
# cr :  2.2010970199601947
